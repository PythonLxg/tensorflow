# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# 对列表进行多热编码
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = \
    keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0
    return results

train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %%
# 查看其中一个多热向量
# 字词索引按频率排序，因此索引 0 附近应该有更多的 1 值
plt.plot(train_data[0])

# %%
baseline_model = keras.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data, train_labels,
                                      epochs=20, batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 6s - loss: 0.5182 - acc: 0.7941 - binary_crossentropy: 0.5182 - val_loss: 0.3683 - val_acc: 0.8694 - val_binary_crossentropy: 0.3683
# Epoch 2/20
#  - 5s - loss: 0.2712 - acc: 0.9055 - binary_crossentropy: 0.2712 - val_loss: 0.2876 - val_acc: 0.8867 - val_binary_crossentropy: 0.2876
# Epoch 3/20
#  - 4s - loss: 0.1949 - acc: 0.9316 - binary_crossentropy: 0.1949 - val_loss: 0.2853 - val_acc: 0.8872 - val_binary_crossentropy: 0.2853
# Epoch 4/20
#  - 4s - loss: 0.1547 - acc: 0.9476 - binary_crossentropy: 0.1547 - val_loss: 0.3051 - val_acc: 0.8803 - val_binary_crossentropy: 0.3051
# Epoch 5/20
#  - 4s - loss: 0.1277 - acc: 0.9584 - binary_crossentropy: 0.1277 - val_loss: 0.3309 - val_acc: 0.8758 - val_binary_crossentropy: 0.3309
# Epoch 6/20
#  - 4s - loss: 0.1063 - acc: 0.9664 - binary_crossentropy: 0.1063 - val_loss: 0.3584 - val_acc: 0.8705 - val_binary_crossentropy: 0.3584
# Epoch 7/20
#  - 4s - loss: 0.0893 - acc: 0.9730 - binary_crossentropy: 0.0893 - val_loss: 0.4101 - val_acc: 0.8638 - val_binary_crossentropy: 0.4101
# Epoch 8/20
#  - 4s - loss: 0.0752 - acc: 0.9780 - binary_crossentropy: 0.0752 - val_loss: 0.4344 - val_acc: 0.8635 - val_binary_crossentropy: 0.4344
# Epoch 9/20
#  - 4s - loss: 0.0614 - acc: 0.9841 - binary_crossentropy: 0.0614 - val_loss: 0.4828 - val_acc: 0.8610 - val_binary_crossentropy: 0.4828
# Epoch 10/20
#  - 4s - loss: 0.0498 - acc: 0.9884 - binary_crossentropy: 0.0498 - val_loss: 0.5416 - val_acc: 0.8555 - val_binary_crossentropy: 0.5416
# Epoch 11/20
#  - 4s - loss: 0.0407 - acc: 0.9912 - binary_crossentropy: 0.0407 - val_loss: 0.5888 - val_acc: 0.8561 - val_binary_crossentropy: 0.5888
# Epoch 12/20
#  - 4s - loss: 0.0308 - acc: 0.9940 - binary_crossentropy: 0.0308 - val_loss: 0.6397 - val_acc: 0.8551 - val_binary_crossentropy: 0.6397
# Epoch 13/20
#  - 4s - loss: 0.0233 - acc: 0.9962 - binary_crossentropy: 0.0233 - val_loss: 0.6929 - val_acc: 0.8522 - val_binary_crossentropy: 0.6929
# Epoch 14/20
#  - 4s - loss: 0.0171 - acc: 0.9980 - binary_crossentropy: 0.0171 - val_loss: 0.7387 - val_acc: 0.8515 - val_binary_crossentropy: 0.7387
# Epoch 15/20
#  - 4s - loss: 0.0125 - acc: 0.9992 - binary_crossentropy: 0.0125 - val_loss: 0.7875 - val_acc: 0.8509 - val_binary_crossentropy: 0.7875
# Epoch 16/20
#  - 4s - loss: 0.0091 - acc: 0.9995 - binary_crossentropy: 0.0091 - val_loss: 0.8230 - val_acc: 0.8497 - val_binary_crossentropy: 0.8230
# Epoch 17/20
#  - 4s - loss: 0.0066 - acc: 0.9999 - binary_crossentropy: 0.0066 - val_loss: 0.8584 - val_acc: 0.8495 - val_binary_crossentropy: 0.8584
# Epoch 18/20
#  - 4s - loss: 0.0051 - acc: 0.9998 - binary_crossentropy: 0.0051 - val_loss: 0.8939 - val_acc: 0.8489 - val_binary_crossentropy: 0.8939
# Epoch 19/20
#  - 4s - loss: 0.0039 - acc: 1.0000 - binary_crossentropy: 0.0039 - val_loss: 0.9104 - val_acc: 0.8492 - val_binary_crossentropy: 0.9104
# Epoch 20/20
#  - 4s - loss: 0.0031 - acc: 1.0000 - binary_crossentropy: 0.0031 - val_loss: 0.9410 - val_acc: 0.8487 - val_binary_crossentropy: 0.9410

# %%
# 创建一个更小的模型
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

smaller_model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['accuracy', 'binary_crossentropy'])
    
smaller_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data, train_labels,
                                    epochs=20, batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 0.6060 - acc: 0.6652 - binary_crossentropy: 0.6060 - val_loss: 0.5453 - val_acc: 0.7766 - val_binary_crossentropy: 0.5453
# Epoch 2/20
#  - 4s - loss: 0.4979 - acc: 0.8368 - binary_crossentropy: 0.4979 - val_loss: 0.4938 - val_acc: 0.8467 - val_binary_crossentropy: 0.4938
# Epoch 3/20
#  - 4s - loss: 0.4479 - acc: 0.8856 - binary_crossentropy: 0.4479 - val_loss: 0.4670 - val_acc: 0.8610 - val_binary_crossentropy: 0.4670
# Epoch 4/20
#  - 4s - loss: 0.4135 - acc: 0.9124 - binary_crossentropy: 0.4135 - val_loss: 0.4518 - val_acc: 0.8642 - val_binary_crossentropy: 0.4518
# Epoch 5/20
#  - 4s - loss: 0.3862 - acc: 0.9274 - binary_crossentropy: 0.3862 - val_loss: 0.4476 - val_acc: 0.8579 - val_binary_crossentropy: 0.4476
# Epoch 6/20
#  - 4s - loss: 0.3631 - acc: 0.9409 - binary_crossentropy: 0.3631 - val_loss: 0.4370 - val_acc: 0.8673 - val_binary_crossentropy: 0.4370
# Epoch 7/20
#  - 4s - loss: 0.3429 - acc: 0.9500 - binary_crossentropy: 0.3429 - val_loss: 0.4315 - val_acc: 0.8712 - val_binary_crossentropy: 0.4315
# Epoch 8/20
#  - 4s - loss: 0.3251 - acc: 0.9570 - binary_crossentropy: 0.3251 - val_loss: 0.4362 - val_acc: 0.8650 - val_binary_crossentropy: 0.4362
# Epoch 9/20
#  - 4s - loss: 0.3088 - acc: 0.9614 - binary_crossentropy: 0.3088 - val_loss: 0.4336 - val_acc: 0.8660 - val_binary_crossentropy: 0.4336
# Epoch 10/20
#  - 4s - loss: 0.2939 - acc: 0.9664 - binary_crossentropy: 0.2939 - val_loss: 0.4372 - val_acc: 0.8645 - val_binary_crossentropy: 0.4372
# Epoch 11/20
#  - 4s - loss: 0.2799 - acc: 0.9700 - binary_crossentropy: 0.2799 - val_loss: 0.4347 - val_acc: 0.8664 - val_binary_crossentropy: 0.4347
# Epoch 12/20
#  - 4s - loss: 0.2671 - acc: 0.9732 - binary_crossentropy: 0.2671 - val_loss: 0.4373 - val_acc: 0.8649 - val_binary_crossentropy: 0.4373
# Epoch 13/20
#  - 4s - loss: 0.2550 - acc: 0.9767 - binary_crossentropy: 0.2550 - val_loss: 0.4427 - val_acc: 0.8628 - val_binary_crossentropy: 0.4427
# Epoch 14/20
#  - 4s - loss: 0.2438 - acc: 0.9785 - binary_crossentropy: 0.2438 - val_loss: 0.4525 - val_acc: 0.8614 - val_binary_crossentropy: 0.4525
# Epoch 15/20
#  - 4s - loss: 0.2333 - acc: 0.9804 - binary_crossentropy: 0.2333 - val_loss: 0.4557 - val_acc: 0.8610 - val_binary_crossentropy: 0.4557
# Epoch 16/20
#  - 4s - loss: 0.2238 - acc: 0.9824 - binary_crossentropy: 0.2238 - val_loss: 0.4577 - val_acc: 0.8625 - val_binary_crossentropy: 0.4577
# Epoch 17/20
#  - 4s - loss: 0.2150 - acc: 0.9829 - binary_crossentropy: 0.2150 - val_loss: 0.4664 - val_acc: 0.8604 - val_binary_crossentropy: 0.4664
# Epoch 18/20
#  - 4s - loss: 0.2065 - acc: 0.9845 - binary_crossentropy: 0.2065 - val_loss: 0.4779 - val_acc: 0.8590 - val_binary_crossentropy: 0.4779
# Epoch 19/20
#  - 4s - loss: 0.1985 - acc: 0.9850 - binary_crossentropy: 0.1985 - val_loss: 0.4792 - val_acc: 0.8600 - val_binary_crossentropy: 0.4792
# Epoch 20/20
#  - 4s - loss: 0.1911 - acc: 0.9858 - binary_crossentropy: 0.1911 - val_loss: 0.5112 - val_acc: 0.8568 - val_binary_crossentropy: 0.5112

# %%
# 创建一个更大的模型
bigger_model = keras.models.Sequential([
    keras.layers.Dense(64, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy', 'binary_crossentropy'])

bigger_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 64)                640064
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 644,289
# Trainable params: 644,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20, batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 2.3876e-04 - acc: 1.0000 - binary_crossentropy: 2.3876e-04 - val_loss: 1.0314 - val_acc: 0.8550 - val_binary_crossentropy: 1.0314
# Epoch 2/20
#  - 5s - loss: 2.0612e-04 - acc: 1.0000 - binary_crossentropy: 2.0612e-04 - val_loss: 1.0449 - val_acc: 0.8549 - val_binary_crossentropy: 1.0449
# Epoch 3/20
#  - 5s - loss: 1.7899e-04 - acc: 1.0000 - binary_crossentropy: 1.7899e-04 - val_loss: 1.0578 - val_acc: 0.8546 - val_binary_crossentropy: 1.0578
# Epoch 4/20
#  - 5s - loss: 1.5648e-04 - acc: 1.0000 - binary_crossentropy: 1.5648e-04 - val_loss: 1.0694 - val_acc: 0.8547 - val_binary_crossentropy: 1.0694
# Epoch 5/20
#  - 5s - loss: 1.3774e-04 - acc: 1.0000 - binary_crossentropy: 1.3774e-04 - val_loss: 1.0803 - val_acc: 0.8547 - val_binary_crossentropy: 1.0803
# Epoch 6/20
#  - 5s - loss: 1.2169e-04 - acc: 1.0000 - binary_crossentropy: 1.2169e-04 - val_loss: 1.0916 - val_acc: 0.8547 - val_binary_crossentropy: 1.0916
# Epoch 7/20
#  - 5s - loss: 1.0825e-04 - acc: 1.0000 - binary_crossentropy: 1.0825e-04 - val_loss: 1.1017 - val_acc: 0.8547 - val_binary_crossentropy: 1.1017
# Epoch 8/20
#  - 5s - loss: 9.6826e-05 - acc: 1.0000 - binary_crossentropy: 9.6826e-05 - val_loss: 1.1118 - val_acc: 0.8548 - val_binary_crossentropy: 1.1118
# Epoch 9/20
#  - 5s - loss: 8.6824e-05 - acc: 1.0000 - binary_crossentropy: 8.6824e-05 - val_loss: 1.1208 - val_acc: 0.8548 - val_binary_crossentropy: 1.1208
# Epoch 10/20
#  - 5s - loss: 7.8264e-05 - acc: 1.0000 - binary_crossentropy: 7.8264e-05 - val_loss: 1.1302 - val_acc: 0.8546 - val_binary_crossentropy: 1.1302
# Epoch 11/20
#  - 5s - loss: 7.0898e-05 - acc: 1.0000 - binary_crossentropy: 7.0898e-05 - val_loss: 1.1391 - val_acc: 0.8546 - val_binary_crossentropy: 1.1391
# Epoch 12/20
#  - 5s - loss: 6.4458e-05 - acc: 1.0000 - binary_crossentropy: 6.4458e-05 - val_loss: 1.1470 - val_acc: 0.8548 - val_binary_crossentropy: 1.1470
# Epoch 13/20
#  - 5s - loss: 5.8783e-05 - acc: 1.0000 - binary_crossentropy: 5.8783e-05 - val_loss: 1.1548 - val_acc: 0.8549 - val_binary_crossentropy: 1.1548
# Epoch 14/20
#  - 5s - loss: 5.3702e-05 - acc: 1.0000 - binary_crossentropy: 5.3702e-05 - val_loss: 1.1619 - val_acc: 0.8550 - val_binary_crossentropy: 1.1619
# Epoch 15/20
#  - 5s - loss: 4.9317e-05 - acc: 1.0000 - binary_crossentropy: 4.9317e-05 - val_loss: 1.1697 - val_acc: 0.8547 - val_binary_crossentropy: 1.1697
# Epoch 16/20
#  - 5s - loss: 4.5363e-05 - acc: 1.0000 - binary_crossentropy: 4.5363e-05 - val_loss: 1.1768 - val_acc: 0.8547 - val_binary_crossentropy: 1.1768
# Epoch 17/20
#  - 5s - loss: 4.1855e-05 - acc: 1.0000 - binary_crossentropy: 4.1855e-05 - val_loss: 1.1834 - val_acc: 0.8547 - val_binary_crossentropy: 1.1834
# Epoch 18/20
#  - 5s - loss: 3.8675e-05 - acc: 1.0000 - binary_crossentropy: 3.8675e-05 - val_loss: 1.1896 - val_acc: 0.8550 - val_binary_crossentropy: 1.1896
# Epoch 19/20
#  - 5s - loss: 3.5868e-05 - acc: 1.0000 - binary_crossentropy: 3.5868e-05 - val_loss: 1.1957 - val_acc: 0.8550 - val_binary_crossentropy: 1.1957
# Epoch 20/20
#  - 5s - loss: 3.3309e-05 - acc: 1.0000 - binary_crossentropy: 3.3309e-05 - val_loss: 1.2021 - val_acc: 0.8546 - val_binary_crossentropy: 1.2021

# %%
# 绘制训练损失和验证损失图表
def plot_history(histories, key='binary_crossentropy'):
    plt.figure(figsize=(16,10))

    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_'+key],
                       '--', label=name.title()+' Val')
        plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
                 label=name.title()+' Train')

    plt.xlabel('Epochs')
    plt.ylabel(key.replace('_',' ').title())
    plt.legend()

    plt.xlim([0,max(history.epoch)])

plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %%
# 添加权重正则化
# 添加L2权重正则化
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20, batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 0.5081 - acc: 0.8065 - binary_crossentropy: 0.4670 - val_loss: 0.3672 - val_acc: 0.8805 - val_binary_crossentropy: 0.3240
# Epoch 2/20
#  - 4s - loss: 0.2922 - acc: 0.9144 - binary_crossentropy: 0.2453 - val_loss: 0.3330 - val_acc: 0.8884 - val_binary_crossentropy: 0.2833
# Epoch 3/20
#  - 4s - loss: 0.2433 - acc: 0.9347 - binary_crossentropy: 0.1911 - val_loss: 0.3405 - val_acc: 0.8862 - val_binary_crossentropy: 0.2866
# Epoch 4/20
#  - 4s - loss: 0.2206 - acc: 0.9443 - binary_crossentropy: 0.1651 - val_loss: 0.3581 - val_acc: 0.8801 - val_binary_crossentropy: 0.3013
# Epoch 5/20
#  - 4s - loss: 0.2066 - acc: 0.9508 - binary_crossentropy: 0.1483 - val_loss: 0.3747 - val_acc: 0.8763 - val_binary_crossentropy: 0.3152
# Epoch 6/20
#  - 4s - loss: 0.1966 - acc: 0.9542 - binary_crossentropy: 0.1361 - val_loss: 0.3896 - val_acc: 0.8732 - val_binary_crossentropy: 0.3283
# Epoch 7/20
#  - 4s - loss: 0.1880 - acc: 0.9579 - binary_crossentropy: 0.1258 - val_loss: 0.4059 - val_acc: 0.8708 - val_binary_crossentropy: 0.3431
# Epoch 8/20
#  - 4s - loss: 0.1821 - acc: 0.9600 - binary_crossentropy: 0.1184 - val_loss: 0.4353 - val_acc: 0.8648 - val_binary_crossentropy: 0.3709
# Epoch 9/20
#  - 4s - loss: 0.1807 - acc: 0.9605 - binary_crossentropy: 0.1154 - val_loss: 0.4383 - val_acc: 0.8663 - val_binary_crossentropy: 0.3723
# Epoch 10/20
#  - 4s - loss: 0.1701 - acc: 0.9672 - binary_crossentropy: 0.1039 - val_loss: 0.4508 - val_acc: 0.8643 - val_binary_crossentropy: 0.3844
# Epoch 11/20
#  - 4s - loss: 0.1651 - acc: 0.9680 - binary_crossentropy: 0.0985 - val_loss: 0.4630 - val_acc: 0.8623 - val_binary_crossentropy: 0.3963
# Epoch 12/20
#  - 4s - loss: 0.1672 - acc: 0.9655 - binary_crossentropy: 0.0997 - val_loss: 0.4887 - val_acc: 0.8585 - val_binary_crossentropy: 0.4201
# Epoch 13/20
#  - 4s - loss: 0.1637 - acc: 0.9679 - binary_crossentropy: 0.0946 - val_loss: 0.4877 - val_acc: 0.8602 - val_binary_crossentropy: 0.4184
# Epoch 14/20
#  - 4s - loss: 0.1639 - acc: 0.9675 - binary_crossentropy: 0.0942 - val_loss: 0.5113 - val_acc: 0.8582 - val_binary_crossentropy: 0.4409
# Epoch 15/20
#  - 4s - loss: 0.1572 - acc: 0.9710 - binary_crossentropy: 0.0865 - val_loss: 0.5206 - val_acc: 0.8577 - val_binary_crossentropy: 0.4499
# Epoch 16/20
#  - 4s - loss: 0.1481 - acc: 0.9756 - binary_crossentropy: 0.0779 - val_loss: 0.5158 - val_acc: 0.8582 - val_binary_crossentropy: 0.4462
# Epoch 17/20
#  - 5s - loss: 0.1427 - acc: 0.9773 - binary_crossentropy: 0.0733 - val_loss: 0.5434 - val_acc: 0.8553 - val_binary_crossentropy: 0.4738
# Epoch 18/20
#  - 4s - loss: 0.1429 - acc: 0.9780 - binary_crossentropy: 0.0733 - val_loss: 0.5420 - val_acc: 0.8573 - val_binary_crossentropy: 0.4723
# Epoch 19/20
#  - 4s - loss: 0.1428 - acc: 0.9769 - binary_crossentropy: 0.0725 - val_loss: 0.5586 - val_acc: 0.8551 - val_binary_crossentropy: 0.4879
# Epoch 20/20
#  - 4s - loss: 0.1396 - acc: 0.9784 - binary_crossentropy: 0.0690 - val_loss: 0.5629 - val_acc: 0.8542 - val_binary_crossentropy: 0.4922

# %%
plot_history([
    ('baseline', baseline_history),
    ('l2', l2_model_history)
])

# %%
# 添加丢弃层
# 在训练期间随机“丢弃”（即设置为 0）该层的多个输出特征.在测试时，网络不会丢弃任何单元，而是将层的输出值按等同于丢弃率的比例进行缩减
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy', 'binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20, batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 0.6385 - acc: 0.6237 - binary_crossentropy: 0.6385 - val_loss: 0.5149 - val_acc: 0.8443 - val_binary_crossentropy: 0.5149
# Epoch 2/20
#  - 4s - loss: 0.4787 - acc: 0.7834 - binary_crossentropy: 0.4787 - val_loss: 0.3607 - val_acc: 0.8781 - val_binary_crossentropy: 0.3607
# Epoch 3/20
#  - 4s - loss: 0.3749 - acc: 0.8527 - binary_crossentropy: 0.3749 - val_loss: 0.3010 - val_acc: 0.8872 - val_binary_crossentropy: 0.3010
# Epoch 4/20
#  - 4s - loss: 0.3153 - acc: 0.8842 - binary_crossentropy: 0.3153 - val_loss: 0.2811 - val_acc: 0.8894 - val_binary_crossentropy: 0.2811
# Epoch 5/20
#  - 4s - loss: 0.2754 - acc: 0.9055 - binary_crossentropy: 0.2754 - val_loss: 0.2825 - val_acc: 0.8884 - val_binary_crossentropy: 0.2825
# Epoch 6/20
#  - 4s - loss: 0.2497 - acc: 0.9144 - binary_crossentropy: 0.2497 - val_loss: 0.2871 - val_acc: 0.8861 - val_binary_crossentropy: 0.2871
# Epoch 7/20
#  - 4s - loss: 0.2205 - acc: 0.9275 - binary_crossentropy: 0.2205 - val_loss: 0.2946 - val_acc: 0.8856 - val_binary_crossentropy: 0.2946
# Epoch 8/20
#  - 4s - loss: 0.1963 - acc: 0.9346 - binary_crossentropy: 0.1963 - val_loss: 0.3121 - val_acc: 0.8830 - val_binary_crossentropy: 0.3121
# Epoch 9/20
#  - 4s - loss: 0.1785 - acc: 0.9418 - binary_crossentropy: 0.1785 - val_loss: 0.3290 - val_acc: 0.8826 - val_binary_crossentropy: 0.3290
# Epoch 10/20
#  - 4s - loss: 0.1664 - acc: 0.9415 - binary_crossentropy: 0.1664 - val_loss: 0.3308 - val_acc: 0.8793 - val_binary_crossentropy: 0.3308
# Epoch 11/20
#  - 4s - loss: 0.1564 - acc: 0.9465 - binary_crossentropy: 0.1564 - val_loss: 0.3613 - val_acc: 0.8803 - val_binary_crossentropy: 0.3613
# Epoch 12/20
#  - 4s - loss: 0.1437 - acc: 0.9502 - binary_crossentropy: 0.1437 - val_loss: 0.3657 - val_acc: 0.8794 - val_binary_crossentropy: 0.3657
# Epoch 13/20
#  - 4s - loss: 0.1333 - acc: 0.9536 - binary_crossentropy: 0.1333 - val_loss: 0.3795 - val_acc: 0.8779 - val_binary_crossentropy: 0.3795
# Epoch 14/20
#  - 4s - loss: 0.1235 - acc: 0.9568 - binary_crossentropy: 0.1235 - val_loss: 0.4248 - val_acc: 0.8799 - val_binary_crossentropy: 0.4248
# Epoch 15/20
#  - 4s - loss: 0.1133 - acc: 0.9595 - binary_crossentropy: 0.1133 - val_loss: 0.4536 - val_acc: 0.8798 - val_binary_crossentropy: 0.4536
# Epoch 16/20
#  - 4s - loss: 0.1089 - acc: 0.9606 - binary_crossentropy: 0.1089 - val_loss: 0.4612 - val_acc: 0.8787 - val_binary_crossentropy: 0.4612
# Epoch 17/20
#  - 4s - loss: 0.1014 - acc: 0.9626 - binary_crossentropy: 0.1014 - val_loss: 0.4707 - val_acc: 0.8770 - val_binary_crossentropy: 0.4707
# Epoch 18/20
#  - 4s - loss: 0.0975 - acc: 0.9635 - binary_crossentropy: 0.0975 - val_loss: 0.5174 - val_acc: 0.8776 - val_binary_crossentropy: 0.5174
# Epoch 19/20
#  - 4s - loss: 0.0951 - acc: 0.9638 - binary_crossentropy: 0.0951 - val_loss: 0.5118 - val_acc: 0.8753 - val_binary_crossentropy: 0.5118
# Epoch 20/20
#  - 4s - loss: 0.0944 - acc: 0.9638 - binary_crossentropy: 0.0944 - val_loss: 0.5297 - val_acc: 0.8764 - val_binary_crossentropy: 0.5297

# %%
plot_history([
    ('baseline', baseline_history),
    ('dropout', dpt_model_history)
])

# %% [raw]
# 下面总结一下防止神经网络出现过拟合的最常见方法：
#
# 1 获取更多训练数据。
# 2 降低网络容量。
# 3 添加权重正则化。
# 4 添加丢弃层
